# %% [markdown]
# <a href="https://colab.research.google.com/github/nurayyubov/GitHub-repos/blob/main/california_hw_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns = data.feature_names)
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df[['MedInc', 'AveRooms']].describe()
# Out:
#              MedInc      AveRooms
# count  20640.000000  20640.000000
# mean       3.870671      5.429000
# std        1.899822      2.474173
# min        0.499900      0.846154
# 25%        2.563400      4.440716
# 50%        3.534800      5.229129
# 75%        4.743250      6.052381
# max       15.000100    141.909091

# %%
df[['MedInc', 'AveRooms']].cov()
# Out:
#             MedInc  AveRooms
# MedInc    3.609323  1.536568
# AveRooms  1.536568  6.121533

# %%
df[['MedInc', 'AveRooms']].corr()
# Out:
#             MedInc  AveRooms
# MedInc    1.000000  0.326895
# AveRooms  0.326895  1.000000

# %% [markdown]
# 0.3 bu musbat lekin zaif bo'g'lanish. daromad oshishi sayin o'rtacha xonalar soni biroz oshgan.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = df['MedInc']
y = df['AveRooms']
plt.scatter(x,y)

plt.title("daromad va xonalar o'rtasidagi bog'liqlik")
plt.xlabel('MedInc')
plt.ylabel('AveRooms')

plt.show()

# %% [markdown]
# 1. bo'g'liqlik past. ko'p xonali uylarni asosan income 1 va 6 oralig'idagi insonlar sotib olishgan. lekin buning sababi ular shahar markazlaridan uzoqroqda yashaganliklari bo'lishi ham mumkin(longtitude va latitude ustunlari bekorga bor emas)
# 2. pastda va chaproqda nuqtalar zich. pastdan o'ngga sayozlashib borgan
